# %% [markdown]
# #EDA Tips dataset

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

from tipsdata import TipsData
from tipspipe import TipsPipe

plt.style.use('bmh')

# %% [markdown]
# ## Data download
# Data is downloaded  using TipsData class. It checks if data exists, if not sets up file structure and downloads data to raw folder.The class can return raw data or data split in train, val and test. Since the dataset is clean there is no need for a process pipeline.

# %%
dataset = TipsData()
dataset.prepare_data(train_split = 0.8, val_split = 0.2, test_split = 0.)
dataset.setup()

# %% [markdown]
# Returns the full raw dataset in a dataframe with features and labels in XY, only features in X and only lables in y.
# Checking table properities shape, feature names and type and label name.

# %%
XY, X,y = dataset.get_raw_data()

print(f'X shape: {X.shape}, y shape: {y.shape}')
print(f'X columns: {X.columns}\n')
print(f'X feature types: \n {X.dtypes}\n')
print(f'y label type: \n {y.dtypes}')
# Out:
# X shape: (244, 6), y shape: (244, 1)
# X columns: Index(['tip', 'sex', 'smoker', 'day', 'time', 'g_size'], dtype='object')
#
# X feature types:
#  tip       float64
# sex        object
# smoker     object
# day        object
# time       object
# g_size      int64
# dtype: object
#
# y label type:
#  total_bill    float64
# dtype: object

# %% [markdown]
# Get unique categorical classes.

# %%
#Get unique values
disc_feature_list = X.select_dtypes(exclude='float64').columns
disc_dict = {}
for i in disc_feature_list:
    print(f'{i}: {X[i].unique()}')
    disc_dict[i] = X[i].unique()
# Out:
# sex: ['Female' 'Male']
# smoker: ['No' 'Yes']
# day: ['Sun' 'Sat' 'Thur' 'Fri']
# time: ['Dinner' 'Lunch']
# g_size: [2 3 4 1 6 5]

# %%
#Check class balance

plt.figure(figsize=(7,8), dpi=125)
for i,k in enumerate(disc_dict):
    plt.subplot(3,2,i+1)
    sns.barplot(x=disc_dict[k], y=X[k].value_counts())
    plt.title(k)
    plt.tight_layout()

plt.show()

# %%
# Check distributions of continuous variables total_bill and tip

# %%
#Check categorical feature's correlation to label
yy = 'total_bill'
plt.figure(figsize=(7,8), dpi=125)
for i,k in enumerate(disc_dict):
    plt.subplot(3,2,i+1)
    sns.boxplot(x=XY[k], y=yy, data=XY)
    plt.title(k)
    plt.tight_layout()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Check distribution of continuous features

plt.figure(figsize=(7,3), dpi=125)
plt.subplot(1,2,1)
sns.histplot(data=XY, x='tip', kde=True)
plt.title('tip Data Distribution')

plt.subplot(1,2,2)
sns.histplot(data=XY, x='total_bill', kde=True)
plt.title('total_bill Data Distribution')
plt.show()

# %%
# 
from scipy.stats import pearsonr

corr, _ = pearsonr(XY['total_bill'].to_numpy(),XY['tip'].to_numpy())
print(corr)

a = np.log(XY['total_bill'].to_numpy())
b = np.log(XY['tip'].to_numpy())

plt.figure(figsize=(5,3), dpi=125)
plt.scatter(a,b, s=15)
plt.xlabel("total_bill")
plt.ylabel("tip")
plt.title('total_bill - tip Correlation Check')
plt.show()
# Out:
# 0.6757341092113647

# %%
#Fit the pipe for data transformation
lr_pipe = TipsPipe()
lr_pipe.make_preprocessor(cat_list=['time'], num_list=['tip'], count_list=['g_size'], pass_list=[])
x,y = dataset.get_train_data()
xval, yval = dataset.get_val_data()
lr_pipe.train_pipe()
xtrain_pipe = lr_pipe.transform_data(x)
xval_pipe = lr_pipe.transform_data(xval)

# %%
from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression, ElasticNet, RidgeCV, Lasso
from sklearn.pipeline import Pipeline
import joblib
import pathlib 

DATA_DIR = pathlib.Path().resolve() / "data"

regressors = {'Linear_regression': LinearRegression(), 'Ridge': RidgeCV(), 'Lasso': Lasso(alpha=0.001), 'Elasticnet': ElasticNet(alpha=0.1, l1_ratio=0.4)}
preds_lin = {}
for k,v in regressors.items():
    lin_pipe = Pipeline(steps=[lr_pipe.get_preprocessor(), ('model',v)])

    lin_pipe.fit(x,y)
        
    fname = DATA_DIR / str(k + '.joblib')
    joblib.dump(lin_pipe, fname)
    
    y_hat = lin_pipe.predict(xval)
    
    r2 = r2_score(yval, y_hat)
    rmse1 = np.sqrt(mean_squared_error(yval, y_hat))
    mae = mean_absolute_error(yval, y_hat)
    mape = mean_absolute_percentage_error(yval, y_hat)
    print(f'{k} model r2 score: {r2:.3f}, rmse: {rmse1:.3f}, mae: {mae:.3f}, mape: {mape:.3f}')
    
    preds_lin[k] = np.array(y_hat).reshape(len(y_hat),1)
# Out:
# Linear_regression model r2 score: 0.516, rmse: 6.608, mae: 4.927, mape: 0.251
# Ridge model r2 score: 0.515, rmse: 6.610, mae: 4.959, mape: 0.255
# Lasso model r2 score: 0.515, rmse: 6.609, mae: 4.928, mape: 0.251
# Elasticnet model r2 score: 0.512, rmse: 6.635, mae: 5.002, mape: 0.259

# %%
# Add residual normality check
import statsmodels.api as sm

model = joblib.load('data/Linear_regression.joblib')

pred_train = model.predict(x)
residuals = pred_train - y.to_numpy()

fig = plt.figure(figsize=(20,5), dpi=125)
ax1 = fig.add_subplot(1,3,1)
plt.hist(residuals, bins=20)
ax1.set_xlabel('Residuals')
ax1.set_ylabel('No of Samples')
ax1.set_title('Histogram of Residuals')

ax2 = fig.add_subplot(1,3,2)
sm.qqplot(residuals[:,0], line='q', ax=ax2)
ax2.set_title('QQ-plot')

ax3 = fig.add_subplot(1,3,3)
ax3.scatter(pred_train, residuals)
ax3.set_xlabel("Predicted values")
ax3.set_ylabel("Residuals")
ax3.set_title("Residuals vs Predicted Values")
fig.show()

# %%
x,y = dataset.get_train_data()
xval, yval = dataset.get_val_data()
tt_pipe = TipsPipe()
regressors = {'Linear_regression': LinearRegression(), 'Ridge': RidgeCV(), 'Lasso': Lasso(alpha=0.001), 'Elasticnet': ElasticNet(alpha=0.1, l1_ratio=0.4)}
preds_tt = {}
for k,v in regressors.items():
    tt_linreg = tt_pipe.make_preprocessor2(cat_list=['time'], num_list=['tip'], 
                                           count_list=['g_size'], pass_list=[], model=v)
    fname = DATA_DIR / str('tt' + k + '.joblib')
    joblib.dump(tt_linreg, fname)
    y_hat = tt_linreg.predict(xval)
    
    r2 = r2_score(yval, y_hat)
    rmse1 = np.sqrt(mean_squared_error(yval, y_hat))
    mae = mean_absolute_error(yval, y_hat)
    mape = mean_absolute_percentage_error(yval, y_hat)
    print(f'{k} model r2 score: {r2:.3f}, rmse: {rmse1:.3f}, mae: {mae:.3f}, mape: {mape:.3f}')
        
    preds_tt[k] = np.array(y_hat).reshape(len(y_hat),1)
# Out:
# Linear_regression model r2 score: 0.530, rmse: 6.512, mae: 4.760, mape: 0.238
# Ridge model r2 score: 0.528, rmse: 6.522, mae: 4.782, mape: 0.240
# Lasso model r2 score: 0.529, rmse: 6.516, mae: 4.767, mape: 0.238
# Elasticnet model r2 score: 0.508, rmse: 6.656, mae: 4.934, mape: 0.251

# %%
model = joblib.load('data/ttLinear_regression.joblib')
print(model.regressor_[:-1].get_feature_names_out())
# Out:
# ['log_nums__tip' 'nums__g_size' 'cats__time_Lunch']

# %%
# Add residual normality check
import statsmodels.api as sm

model = joblib.load('data/ttLinear_regression.joblib')

pred_train = model.predict(x)
residuals = pred_train - y.to_numpy()

fig = plt.figure(figsize=(20,5), dpi=125)
ax1 = fig.add_subplot(1,3,1)
plt.hist(residuals, bins=20)
ax1.set_xlabel('Residuals')
ax1.set_ylabel('No of Samples')
ax1.set_title('Histogram of Residuals')

ax2 = fig.add_subplot(1,3,2)
sm.qqplot(residuals[:,0], line='q', ax=ax2)
ax2.set_title('QQ-plot')

ax3 = fig.add_subplot(1,3,3)
ax3.scatter(pred_train, residuals)
ax3.set_xlabel("Predicted values")
ax3.set_ylabel("Residuals")
ax3.set_title("Residuals vs Predicted Values")
fig.show()

# %%
pred_train = model.predict(x)
res_error = y - pred_train

error_arr = np.concatenate((y, pred_train, res_error, x), axis=1)

er_df = pd.DataFrame(data=error_arr, columns=['y', 'pred','error'] + x.columns.to_list())

large_neg_res = res_error.quantile(.05)[0]
large_pos_res = res_error.quantile(.95)[0]

def col_fcn(row):
    if row['error'] < large_neg_res:
        return 'red'
    elif row['error'] > large_pos_res:
        return 'blue'
    else: return 'green'

er_df['color'] = er_df.apply(col_fcn, axis=1)


print(f'5% largest neg error: {large_neg_res:.2f},\n95% largest pos error: {large_pos_res:.2f}')

plt.figure(figsize=(5,3), dpi=125)
plt.hist(res_error, bins=30)
plt.show()

color_list = ['red', 'green', 'blue']

plt.figure(figsize=(5,3), dpi=125)
plt.scatter(y, res_error, color = er_df.color.to_list(), s=15)
plt.show()
# Out:
# 5% largest neg error: -6.07,
# 95% largest pos error: 12.36

# %%
display(er_df[(er_df['error'] > large_pos_res) | (er_df['error'] < large_neg_res)].sort_values(by=['color', 'error'], ascending=True))
# Out:
#          y       pred      error   tip     sex smoker   day    time g_size  \
# 192  28.44  15.478738  12.961262  2.56    Male    Yes  Thur   Lunch      2
# 173  31.85  18.159465  13.690535  3.18    Male    Yes   Sun  Dinner      2
# 57   26.41  12.192835  14.217165   1.5  Female     No   Sat  Dinner      2
# 112  38.07  23.815145  14.254855   4.0    Male     No   Sun  Dinner      3
# 56   38.01  23.165198  14.844802   3.0    Male    Yes   Sat  Dinner      4
# 175   32.9  17.929022  14.970978  3.11    Male    Yes   Sun  Dinner      2
# 179  34.63  19.356674  15.273326  3.55    Male    Yes   Sun  Dinner      2
# 184  40.55  17.564222  22.985778   3.0    Male    Yes   Sun  Dinner      2
# 182  45.35  22.039115  23.310885   3.5    Male    Yes   Sun  Dinner      3
# 102   44.3  18.267804  26.032196   2.5  Female    Yes   Sat  Dinner      3
# 172   7.25  24.194435 -16.944435  5.15    Male    Yes   Sun  Dinner      2
# 185  20.69  35.413359 -14.723359   5.0    Male     No   Sun  Dinner      5
# 183  23.17  36.363807 -13.193807   6.5    Male    Yes   Sun  Dinner      4
# 141   34.3   46.29736  -11.99736   6.7    Male     No  Thur   Lunch      6
# 143  27.05   38.96731  -11.91731   5.0  Female     No  Thur   Lunch      6
# 178    9.6  20.769193 -11.169193   4.0  Female    Yes   Sun  Dinner      2
# 63   18.29  26.300025  -8.010025  3.76    Male    Yes   Sat  Dinner      4
# 17   16.29  22.792961  -6.502961  3.71    Male     No   Sun  Dinner      3
# 109  14.31  20.769193  -6.459193   4.0  Female    Yes   Sat  Dinner      2
# 155  29.85  35.991835  -6.141835  5.14  Female     No   Sun  Dinner      5
#
#     color
# 192  blue
# 173  blue
# 57   blue
# 112  blue
# 56   blue
# 175  blue
# 179  blue
# 184  blue
# 182  blue
# 102  blue
# 172   red
# 185   red
# 183   red
# 141   red
# 143   red
# 178   red
# 63    red
# 17    red
# 109   red
# 155   red

# %%
#Check categorical feature's correlation to label
x['res_error'] = res_error['total_bill']

corr, _ = pearsonr(x['res_error'].to_numpy(),x['tip'].to_numpy())
print(corr)

plt.figure(figsize=(7,8), dpi=125)
for i,k in enumerate(disc_dict):
    plt.subplot(3,2,i+1)
    sns.boxplot(x=x[k], y='res_error', data=x)
    plt.tight_layout()

plt.show()
# Out:
# -0.03817664667898765

# %%
#Fit the pipe for data transformation
xgb_pipe = TipsPipe()
xgb_pipe.make_preprocessor(cat_list=['sex','smoker','day','time'], num_list=['tip'], count_list=['g_size'], pass_list=[])
x,y = dataset.get_train_data()
xval, yval = dataset.get_val_data()
xgb_pipe.train_pipe()
xtrain_pipe = xgb_pipe.transform_data(x)
xval_pipe = xgb_pipe.transform_data(xval)

features = xgb_pipe.get_pipe()['preprocessor'].get_feature_names_out()
print(features)
print(xtrain_pipe.shape)
print(xval_pipe.shape)
# Out:
# ['log_nums__tip' 'nums__g_size' 'cats__sex_Male' 'cats__smoker_Yes'
#  'cats__day_Sat' 'cats__day_Sun' 'cats__day_Thur' 'cats__time_Lunch']
# (195, 8)
# (48, 8)

# %%
from xgboost import XGBRegressor

#Test model
eval_set = [(xtrain_pipe,y), (xval_pipe, yval)]
eval_metrics = ['mae']

model = XGBRegressor(use_label_encoder=False)

xgb_trained = model.fit(xtrain_pipe,y,
             eval_set=eval_set,
             eval_metric=eval_metrics,
             verbose=True)
# Out:
# [0]	validation_0-mae:13.73855	validation_1-mae:13.50969
# [1]	validation_0-mae:9.88998	validation_1-mae:9.83238
# [2]	validation_0-mae:7.15598	validation_1-mae:7.19340
# [3]	validation_0-mae:5.34494	validation_1-mae:5.66440
# [4]	validation_0-mae:4.15763	validation_1-mae:4.95919
# [5]	validation_0-mae:3.43744	validation_1-mae:4.73040
# [6]	validation_0-mae:2.91301	validation_1-mae:4.73184
# [7]	validation_0-mae:2.61826	validation_1-mae:4.89038
# [8]	validation_0-mae:2.40422	validation_1-mae:5.11519
# [9]	validation_0-mae:2.26528	validation_1-mae:5.17087
# [10]	validation_0-mae:2.19030	validation_1-mae:5.22457
# [11]	validation_0-mae:2.11365	validation_1-mae:5.21741
# [12]	validation_0-mae:2.02542	validation_1-mae:5.22677
# [13]	validation_0-mae:1.93354	validation_1-mae:5.25976
# [14]	validation_0-mae:1.87564	validation_1-mae:5.25117
# [15]	validation_0-mae:1.84351	validation_1-mae:5.24658
# [16]	validation_0-mae:1.79347	validation_1-mae:5.21631
# [17]	validation_0-mae:1.76557	validation_1-mae:5.19958
# [18]	validation_0-mae:1.72138	validation_1-mae:5.21482
# [19]	validation_0-mae:1.69018	validation_1-mae:5.19002
# [20]	validation_0-mae:1.65853	validation_1-mae:5.18036
# [21]	validation_0-mae:1.57484	validation_1-mae:5.25695
# [22]	validation_0-mae:1.50401	validation_1-mae:5.32050
# [23]	validation_0-mae:1.45524	validation_1-mae:5.36160
# [24]	validation_0-mae:1.39417	validation_1-mae:5.37191
# [25]	validation_0-mae:1.32709	validation_1-mae:5.41990
# [26]	validation_0-mae:1.29771	validation_1-mae:5.41295
# [27]	validation_0-mae:1.24986	validation_1-mae:5.39020
# [28]	validation_0-mae:1.22770	validation_1-mae:5.40462
# [29]	validation_0-mae:1.20840	validation_1-mae:5.40571
# [30]	validation_0-mae:1.19821	validation_1-mae:5.41496
# [31]	validation_0-mae:1.15002	validation_1-mae:5.45477
# [32]	validation_0-mae:1.12436	validation_1-mae:5.43361
# [33]	validation_0-mae:1.09968	validation_1-mae:5.43422
# [34]	validation_0-mae:1.05827	validation_1-mae:5.39696
# [35]	validation_0-mae:1.03618	validation_1-mae:5.38887
# [36]	validation_0-mae:1.01506	validation_1-mae:5.39432
# [37]	validation_0-mae:0.95108	validation_1-mae:5.36177
# [38]	validation_0-mae:0.90477	validation_1-mae:5.37093
# [39]	validation_0-mae:0.87365	validation_1-mae:5.33796
# [40]	validation_0-mae:0.86781	validation_1-mae:5.33623
# [41]	validation_0-mae:0.84024	validation_1-mae:5.32951
# [42]	validation_0-mae:0.83579	validation_1-mae:5.33224
# [43]	validation_0-mae:0.79809	validation_1-mae:5.32704
# [44]	validation_0-mae:0.76297	validation_1-mae:5.32334
# [45]	validation_0-mae:0.73651	validation_1-mae:5.32910
# [46]	validation_0-mae:0.72370	validation_1-mae:5.33176
# [47]	validation_0-mae:0.70797	validation_1-mae:5.31806
# [48]	validation_0-mae:0.69875	validation_1-mae:5.32495
# [49]	validation_0-mae:0.69207	validation_1-mae:5.31391
# [50]	validation_0-mae:0.67480	validation_1-mae:5.32445
# [51]	validation_0-mae:0.65026	validation_1-mae:5.32641
# [52]	validation_0-mae:0.62980	validation_1-mae:5.33794
# [53]	validation_0-mae:0.62271	validation_1-mae:5.34190
# [54]	validation_0-mae:0.61304	validation_1-mae:5.35636
# [55]	validation_0-mae:0.60514	validation_1-mae:5.36688
# [56]	validation_0-mae:0.59483	validation_1-mae:5.37489
# [57]	validation_0-mae:0.58836	validation_1-mae:5.36170
# [58]	validation_0-mae:0.56837	validation_1-mae:5.35498
# [59]	validation_0-mae:0.55381	validation_1-mae:5.36456
# [60]	validation_0-mae:0.54707	validation_1-mae:5.36144
# [61]	validation_0-mae:0.53944	validation_1-mae:5.37113
# [62]	validation_0-mae:0.53037	validation_1-mae:5.37037
# [63]	validation_0-mae:0.52346	validation_1-mae:5.38206
# [64]	validation_0-mae:0.51401	validation_1-mae:5.38334
# [65]	validation_0-mae:0.50914	validation_1-mae:5.38929
# [66]	validation_0-mae:0.50477	validation_1-mae:5.38983
# [67]	validation_0-mae:0.50229	validation_1-mae:5.39192
# [68]	validation_0-mae:0.49973	validation_1-mae:5.39670
# [69]	validation_0-mae:0.49367	validation_1-mae:5.39771
# [70]	validation_0-mae:0.48605	validation_1-mae:5.39536
# [71]	validation_0-mae:0.48135	validation_1-mae:5.39856
# [72]	validation_0-mae:0.47817	validation_1-mae:5.39961
# [73]	validation_0-mae:0.47508	validation_1-mae:5.40147
# [74]	validation_0-mae:0.47103	validation_1-mae:5.40385
# [75]	validation_0-mae:0.46780	validation_1-mae:5.40379
# [76]	validation_0-mae:0.46571	validation_1-mae:5.40451
# [77]	validation_0-mae:0.45808	validation_1-mae:5.40470
# [78]	validation_0-mae:0.45471	validation_1-mae:5.40329
# [79]	validation_0-mae:0.45199	validation_1-mae:5.40485
# [80]	validation_0-mae:0.44508	validation_1-mae:5.40972
# [81]	validation_0-mae:0.44287	validation_1-mae:5.40956
# [82]	validation_0-mae:0.43843	validation_1-mae:5.41018
# [83]	validation_0-mae:0.43590	validation_1-mae:5.41027
# [84]	validation_0-mae:0.43034	validation_1-mae:5.41190
# [85]	validation_0-mae:0.42780	validation_1-mae:5.41341
# [86]	validation_0-mae:0.42601	validation_1-mae:5.41409
# [87]	validation_0-mae:0.42486	validation_1-mae:5.41420
# [88]	validation_0-mae:0.42306	validation_1-mae:5.41542
# [89]	validation_0-mae:0.42000	validation_1-mae:5.41547
# [90]	validation_0-mae:0.41472	validation_1-mae:5.41000
# [91]	validation_0-mae:0.41012	validation_1-mae:5.41230
# [92]	validation_0-mae:0.40760	validation_1-mae:5.40944
# [93]	validation_0-mae:0.40578	validation_1-mae:5.40872
# [94]	validation_0-mae:0.40506	validation_1-mae:5.40819
# [95]	validation_0-mae:0.39598	validation_1-mae:5.41026
# [96]	validation_0-mae:0.39166	validation_1-mae:5.41309
# [97]	validation_0-mae:0.38403	validation_1-mae:5.41733
# [98]	validation_0-mae:0.37892	validation_1-mae:5.41702
# [99]	validation_0-mae:0.37501	validation_1-mae:5.41889

# %%
feature_importance = xgb_trained.get_booster().get_score(importance_type='gain')
print(feature_importance)
keys = list(feature_importance.keys())
values = list(feature_importance.values())

plt.figure(figsize=(5,3), dpi=125)
plt.bar(keys, values)
plt.show()
# Out:
# {'f0': 8.26619815826416, 'f1': 15.571329116821289, 'f2': 3.393195390701294, 'f3': 5.125671863555908, 'f4': 3.726058006286621, 'f5': 4.443110466003418, 'f6': 1.5788630247116089}
